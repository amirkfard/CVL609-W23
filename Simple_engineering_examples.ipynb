# %% [markdown]
# ## Problem 1: Bending moment
# Determine the maximum bending moment and shear force in a simply supported beam with a point load of 10 kN applied at the midpoint of the beam, which has a length of 6 m.

# %% [markdown]
# The following code uses the length of the beam and the point load applied to the beam to calculate the maximum bending moment and shear force. The values of length and point load are defined as variables at the beginning of the code. The script then uses these variables to calculate the bending moment and shear force, and it prints the results to the console.
#
# This is a simple problem, but it could be adjusted by adding more complex loads and boundary conditions, and then you can use the same script to solve the problem.

# %%
# Import necessary modules
import math    #It is not necessary for this problem!

# Define inputs
length = 6  # m
point_load = 10  # kN

# Calculate maximum bending moment
bending_moment = point_load * length / 4

# Calculate maximum shear force
shear_force = point_load/2

# Print results
print("Maximum bending moment: ", bending_moment, " kN*m")
print("Maximum shear force: ", shear_force, " kN")
# Out:
# Maximum bending moment:  15.0  kN*m
# Maximum shear force:  5.0  kN

# %% [markdown]
# ## Problem 2: Tank Valume
# Determine the volume of a cylindrical tank with a radius of 2m and a height of 4m.
#
# The following code uses basic mathematical formula to calculate the volume of a cylindrical tank using the radius and height as inputs. And it also uses the numpy library to perform mathematical operations.

# %%
import numpy as np

# Define inputs
r = 2  # radius of the tank (m)
h = 4  # height of the tank (m)

# Calculate the volume
V = np.pi * r**2 * h

print("The volume of the cylindrical tank is {:.2f} m^3".format(V))
# Out:
# The volume of the cylindrical tank is 50.27 m^3

# %% [markdown]
# ## Problem 3 : Cube volume
# Calculate the volume of a cube with a side length of 5 meters. Plot the volume as a function of the side length.
#
# This code calculates the volume of a cube with a side length of 5 meters, and plots the volume as a function of the side length. The code takes as input the side length of the cube. The code calculates the volume using the formula volume = side_length**3. The code returns the volume of the cube. Also, it plotted the results of volume of the cube versus side length.

# %%
import matplotlib.pyplot as plt    # Essential library for plotting in Python
import numpy as np

import seaborn as sns           # Seaborn library makes your makes your plot more beautiful!!!
sns.set_style("darkgrid")     
# sns.set_style("whitegrid")     # Also try "whitegrid " to see the difference in the plot appearance

# Define inputs
side_length = 5 # side length of cube (m)

# Volume calculation
volume = side_length**3

# Plotting the results
x = np.linspace(1, 10, 100)
y = x**3
plt.plot(x, y)
plt.xlabel('Side length (m)')
plt.ylabel('Volume (m^3)')
plt.title('Volume of a cube vs side length')
plt.show()

# %% [markdown]
# ## Problem 4: Plot temperature
# Determine the maximum and minimum temperature of a city for a given month (15 days). The data for the city includes the average temperature for each day of the month and the highest and lowest temperature for each day of the month.
#
# Python code to solve the problem:
#
# This code uses the numpy library to perform mathematical operations. The code uses the array of the temperature data, it calculates the average temperature for each day of the month, maximum and minimum temperature for each day of the month and prints the results.

# %%
import numpy as np

# Define inputs (15 days)
temps = np.array([[13, 30], [12, 32], [15, 35], [18, 40], [20, 42],
                 [17, 38], [14, 34], [12, 30], [10, 28], [8, 26],
                 [5, 22], [2, 20], [-2, 20], [-2, 16], [-5, 12]])

# Calculate the average temperature
average_temps = temps.mean(axis=1)

# Calculate the maximum and minimum temperature
max_temp = np.max(temps[:, 1])
min_temp = np.min(temps[:, 0])

print("The average temperature for the month is {:.2f}C".format(np.mean(average_temps)))
print("The maximum temperature for the month is {:.2f}C".format(max_temp))
print("The minimum temperature for the month is {:.2f}C".format(min_temp))
# Out:
# The average temperature for the month is 18.73C
# The maximum temperature for the month is 42.00C
# The minimum temperature for the month is -5.00C

# %% [markdown]
# ### Plotting the results
#
# here's how you can use the matplotlib library to plot the temperature data from the previous example:

# %%
import matplotlib.pyplot as plt

# Plot the average temperature
plt.plot(average_temps)
plt.xlabel('Day')
plt.ylabel('Temperature (C)')
plt.title('Average temperature for the month')
plt.show()

# Plot the maximum and minimum temperature
plt.plot(temps[:, 1], 'r', label='Maximum temperature')
plt.plot(temps[:, 0], 'b', label='Minimum temperature')
plt.plot(average_temps, label='Average temperature')
plt.xlabel('Day')
plt.ylabel('Temperature (C)')
plt.title('Maximum and minimum temperature for the month')
plt.legend()
plt.show()

# %% [markdown]
# ##Problem 5: Area of a rectangle
# Calculate the area of a rectangle with a length of 5 meters and a width of 3 meters. Plot the area as a function of the length and width.
#
# This code calculates the area of a rectangle with a length of 5 meters and a width of 3 meters, and plots the area as a function of the length and width. The code takes as input the length and width of the rectangle. The code calculates the area using the formula area = length*width. The code returns the area of the rectangle. Also, it plotted the results of area of the rectangle versus length and width in 3D space, where x-axis is length, y-axis is width and z-axis is the area.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
length = 5 # length of rectangle (m)
width = 3 # width of rectangle (m)

# Area calculation
area = length*width

# Plotting the results
x = np.linspace(1, 10, 100)
y = np.linspace(1, 10, 100)
X, Y = np.meshgrid(x, y)
Z = X*Y

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)
ax.set_xlabel('Length (m)')
ax.set_ylabel('Width (m)')
ax.set_zlabel('Area (m^2)')
ax.set_title('Area of a rectangle vs length and width')
plt.show()

# %% [markdown]
# ##Problem 6: Maximum bending moment
# Design a simple beam by determining the maximum bending moment, given the loads and the geometry of the beam. The data includes the loads and the geometry of the beam.
#
# Python code to solve the problem:
#
# This code designs a simple beam by determining the maximum bending moment, given the loads and the geometry of the beam. The code takes as input the loads and the length of the beam. The code calculates the maximum bending moment using the formula moment = loads*length/2. This equation is based on the concept of the maximum bending moment that occurs at the center of the beam (neutral axis) and it's also known as the moment of inertia. The code returns the maximum bending moment. Also, it plotted the results of maximum bending moment versus loads.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
loads = np.linspace(0, 10, 100) # loads (kN)
length = 8 # length of beam (m)

# Bending moment calculation
moment = loads*length/4

# Plotting the results
plt.plot(loads, moment)
plt.xlabel('Loads (kN)')
plt.ylabel('Bending moment (kN-m)')
plt.title('Bending moment vs loads')
plt.show()

# %% [markdown]
# ## Problem 7: Flow of water
# Simulate the flow of water through a pipe with a circular cross-section, with a diameter of 0.1 m and a length of 20 m. The pipe is filled with water at a temperature of 20 °C and a pressure of 10^5 Pa. The pressure drop along the length of the pipe is to be determined.

# %% [markdown]
# The following code uses the diameter, length, viscosity and density of water to calculate the Reynold's number which is used to determine the type of flow (laminar or turbulent). Then it uses the appropriate equation (Poiseuille's equation for laminar flow and Darcy-Weisbach for turbulent flow) to calculate the pressure drop along the length of the pipe and print the result to the console.

# %%
# Import necessary modules
import math

# Define inputs
d = 0.1  # diameter of pipe (m)
L = 20  # length of pipe (m)
v = 0.001  # kinematic viscosity of water (m^2/s)
rho = 997  # density of water (kg/m^3)
g = 9.81  # acceleration due to gravity (m/s^2)

# Calculate Reynold's number
Re = 4 * 0.001 / (math.pi * d * 0.000001)

# Determine type of flow
if Re < 2300:
    print("Laminar flow")
    # Calculate pressure drop using Poiseuille's equation
    deltaP = (8 * rho * L * v) / (math.pi * d**4)
else:
    print("Turbulent flow")
    # Calculate pressure drop using Darcy-Weisbach equation
    f = 0.25 / ((math.log10(3.7 * d/ (0.00001 * L)))**2)
    deltaP = f * (L/d) * (rho * v**2) / 2

# Print result
print("Pressure drop: ", deltaP, " Pa")
# Out:
# Turbulent flow
# Pressure drop:  0.0023350234275017405  Pa

# %% [markdown]
# ## Problem 8: Deflection of concrete slab
# Design a concrete slab by determining the deflection, given the loads and the geometry of the slab. The data includes the loads, the dimensions, and the material properties of the slab.
#
# Python code to solve the problem:
#
# This code designs a concrete slab by determining the deflection, given the loads and the geometry of the slab. The code takes as input the loads, the dimensions, and the material properties of the slab. The code calculates the deflection using the formula deflection = load*(length**3width)/(48youngs_modulus*thickness) based on the concept of the deflection of the concrete slab. This formula is based on the classical plate theory and it's only valid for small deflection. The code returns the deflection of the slab. Also, it plotted the results of deflection of the slab versus load.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
load = np.linspace(0, 100000, 100) # loads (N/m^2)
width = 10 # width of slab (m)
length = 8 # length of slab (m)
thickness = 0.2 # thickness of slab (m)
youngs_modulus = 25e9 # young's modulus of concrete (Pa)

# Deflection calculation
deflection = load*(length**3*width)/(48*youngs_modulus*thickness)

# Plotting the results
plt.plot(load, deflection)
plt.xlabel('Load (kN/m^2)')
plt.ylabel('Deflection (m)')
plt.title('Deflection of concrete slab vs load')
plt.show()

# %% [markdown]
# ##Problem 9: Analyze the water quality
# Analyze the water quality of a river by determining the concentration of pollutants over time. Given the data of pollutants concentration, time and location, plot the results.
#
# Python code to solve the problem:
#
# This code analyzes the water quality of a river by determining the concentration of pollutants over time. The code takes as input the time, location, and the concentration of two pollutants. The code generates random data for the concentration of two pollutants using numpy's random.normal() function with mean and standard deviation as inputs. The code plots the results of the concentration of two pollutants over time.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
time = np.linspace(1, 100, 100) # time (hours)
location = "River X" # location of water sample
pollutant_1 = np.random.normal(0.1, 0.05, 100) # pollutant 1 concentration (mg/L)
pollutant_2 = np.random.normal(0.05, 0.01, 100) # pollutant 2 concentration (mg/L)

# Plotting the results
plt.plot(time, pollutant_1, label='Pollutant 1')
plt.plot(time, pollutant_2, label='Pollutant 2')
plt.xlabel('Time (hours)')
plt.ylabel('Concentration (mg/L)')
plt.title('Water quality at '+location)
plt.legend()
plt.show()

# %% [markdown]
# ##Problem 10: Cantilever beam displacement 1
# Design a cantilever beam by determining the displacement, given the loads and the properties of the beam. The data includes the loads and the properties of the beam.
#
# Python code to solve the problem:
#
# This code designs a cantilever beam by determining the displacement, given the loads and the properties of the beam. The code takes as input the loads, length, elastic modulus and moment of inertia of the beam. The code calculates the displacement using the formula displacement = (loadslength^3)/(3elastic_modulus*moment_of_inertia) based on the concept of the displacement of a cantilever beam. The code returns the displacement of the beam. Also, it plotted the results of displacement of the beam versus loads.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
loads = np.linspace(0, 100000, 100) # loads (N/m^2)
length = 8 # length of beam (m)
elastic_modulus = 200e9 # elastic modulus of the beam material (Pa)
moment_of_inertia = 0.1 # moment of inertia of the beam (m^4)

# Displacement calculation
displacement = (loads*length**3)/(3*elastic_modulus*moment_of_inertia)

# Plotting the results
plt.plot(loads, displacement)
plt.xlabel('Loads (kN)')
plt.ylabel('Displacement (m)')
plt.title('Displacement of cantilever beam vs loads')
plt.show()

# %% [markdown]
# ##Problem 11: Cantilever beam displacement 2
# Determine the displacement of a cantilever beam under a point load at the free end and plot the displacement along the beam length.
#
# Python code to solve the problem and plot the result:
#
# In this example, we first import the necessary libraries: matplotlib to plot the results, and numpy to work with arrays. Then we define the properties of the beam: Young's modulus of the material, second moment of area, length and point load. We then define a function displacement which takes inputs of x, L, P, E and I and returns the displacement of the beam at a given point. Next, we create an array x which represents the positions along the beam. We then use displacement function to calculate the displacement along the beam length. After this, we plot the displacement along the beam length using the matplotlib library.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the properties of the beam
E = 2e11 # Young's modulus of the beam material (Pa)
I = 0.00001 # Second moment of area of the beam (m^4)
L = 2 # Length of the beam (m)
P = 1000 # Point load at the free end of the beam (N)
x = np.linspace(0, L, 100) # Discretize the beam length for plotting

# Define the displacement function
def displacement(x, L, P, E, I):
    """
    This function calculates the displacement of a cantilever beam under a point load
    :param x: position along the beam (m)
    :param L: length of the beam (m)
    :param P: point load at the free end of the beam (N)
    :param E: Young's modulus of the beam material (Pa)
    :param I: Second moment of area of the beam (m^4)
    :return: displacement at position x (m)
    """
    return (P*x**2)/((6*E*I)*(3*L-x))

# Calculate the displacement along the beam length
y = displacement(x, L, P, E, I)

# Plot the displacement along the beam length
plt.plot(x, y)
plt.xlabel('Position along the beam (m)')
plt.ylabel('Displacement (m)')
plt.title('Displacement of a cantilever beam')
plt.show()

# %% [markdown]
# ## Problem 12: Deflection of a simply supported beam
# Determine the deflection of a simply supported beam under a point load using the Euler-Bernoulli beam theory. The beam has a length of 10m, a width of 0.2m, a height of 0.1m, and a Young's modulus of 200GPa. The point load is applied at the center of the beam and has a magnitude of 100N.
#
# Python code to solve the problem:
#
# This code uses basic mathematical formulas from Euler-Bernoulli beam theory to calculate the deflection of a simply supported beam under a point load. It uses the numpy library to perform mathematical operations and to create the x array. The code then uses the matplotlib library to plot the deflection, the x-axis represents the position along the beam and the y-axis represents the deflection.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define inputs
L = 10  # length of the beam (m)
b = 0.2  # width of the beam (m)
h = 0.1  # height of the beam (m)
E = 200e9  # modulus of elasticity (Pa)
P = 100  # point load (N)
x = np.linspace(0, L, 100)

# Calculate the deflection
y = (P*x*(L-x)/(6*E*(b*h**3/12)*L))

# Plot the deflection
plt.plot(x, y)
plt.xlabel('x (m)')
plt.ylabel('Deflection (m)')
plt.title('Deflection of simply supported beam')
plt.show()

# %% [markdown]
# ##Problem 13: Present value
# A construction company is considering building a new office building. The building will cost $10 million to construct and will generate $1.5 million in net cash flow each year for 20 years. The company's cost of capital is 10%. What is the present value of the building?
#
# Python code to solve the problem:
#
# This code uses a for loop to calculate the present value of the building project. The loop starts from 0 to n-1, at each iteration it calculates the present value of cash flow for year i by dividing it by (1+r)^(i+1) where r is the discount rate. It adds the present value of cash flow for each year to the present value of the project and finally, it subtracts the cost of the project. The final result is the present value of the building.

# %%
# Define inputs
cost = 10e6 # project cost in $
cash_flow = 1.5e6 # annual cash flow in $
n = 20 # number of years
r = 0.1 # discount rate

# Calculate present value
pv = 0
for i in range(n):
    pv += cash_flow / (1 + r)**(i+1)
pv -= cost

# Print present value
print("The present value of the building is: ${:.2f}".format(pv))
# Out:
# The present value of the building is: $2770345.58

# %% [markdown]
# ##Problem 14: Present value of a stream of cash flows
# Determine the present value of a stream of cash flows over a period of time, given the cash flows, the discount rate and the number of years.
#
# Python code to solve the problem:
#
# In this example, we define a function called present_value that takes three input parameters: the cash flows (cash_flows), the discount rate (discount_rate) and the number of years (years). The function then calculates the present value of a stream of cash flows using the formula of present value. The function returns the present value of cash flows. The main program then calls the function with the given inputs and prints out the result.

# %%
def present_value(cash_flows, discount_rate, years):
    """
    This function calculates the present value of a stream of cash flows
    :param cash_flows: a list of cash flows (dollars)
    :param discount_rate: the discount rate as a decimal (e.g. 0.05 for 5%)
    :param years: number of years
    :return: present value of cash flows (dollars)
    """
    present_value = 0
    for i, cash_flow in enumerate(cash_flows):
        present_value += cash_flow / (1 + discount_rate) ** (i+1)
    return present_value

cash_flows = [1000, 1100, 1200, 1300] # cash flows over a period of 4 years (dollars)
discount_rate = 0.03 # discount rate as a decimal (e.g. 0.05 for 5%)
years = 4 # number of years

pv = present_value(cash_flows, discount_rate, years)

print("The present value of the cash flows is {:.2f} dollars.".format(pv))
# Out:
# The present value of the cash flows is 4260.93 dollars.

# %% [markdown]
# ##Problem 15: Selecting from design options
# You are a project manager for a construction company and you have to decide which of three potential design options to use for a new building project. Each option has a different cost and energy efficiency rating. You want to choose the option that provides the best cost-efficiency ratio.
#
# Python code to solve the problem:
#
# In this example, we use a numpy array to store the information for the three potential design options. The cost-efficiency ratio is calculated by dividing the cost of the option by its energy efficiency rating. Using the matplotlib library, a bar chart is plotted with the cost-efficiency ratio of the design options on the y-axis and their names on the x-axis. This way it's easy to compare and decide which option provides the best cost-efficiency ratio.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create an array with design options information
design_options = np.array([[150000, 0.9], [120000, 0.8], [140000, 0.7]])

# Calculate the cost-efficiency ratio
cost_efficiency = design_options[:,0]/design_options[:,1]

# Plot the results
fig, ax = plt.subplots()
ax.bar(np.arange(len(design_options)), cost_efficiency)
ax.set_xticks(np.arange(len(design_options)))
ax.set_xticklabels(['Option 1', 'Option 2', 'Option 3'])
ax.set_ylabel('Cost-Efficiency Ratio')
plt.show()

# Find the index of the lowest cost-efficiency ratio
best_option_index = np.argmin(cost_efficiency)

# Print the best design option
print(f'The best design option is: Option {best_option_index+1}')

# Extract the cost and energy efficiency rating of the best option
best_option_cost = design_options[best_option_index, 0]
best_option_efficiency = design_options[best_option_index, 1]

# Print the cost and efficiency of the best option
print(f'Cost of the best option: {best_option_cost}')
print(f'Energy efficiency of the best option: {best_option_efficiency}')
# Out:
# The best design option is: Option 2
# Cost of the best option: 120000.0
# Energy efficiency of the best option: 0.8

# %% [markdown]
# ##Problem 16: Route selection
# You are a project manager for a construction company and you are considering building a new road. There are two possible routes for the road, and you need to decide which route to take. Route A is shorter and has less traffic, but it goes through a nature reserve and would require getting permission from the government. Route B is longer and has more traffic, but it doesn't go through the nature reserve and wouldn't require any special permissions. You want to choose the route that minimizes the total cost and time.

# %%
import pandas as pd

# Create a dataframe with route information
routes = pd.DataFrame({'Route': ['A', 'B'],
                      'Distance': [10, 15],
                      'Traffic': [0.1, 0.2],
                      'Government Permission': [1, 0]})

# Assign cost and time values
cost_per_km = 10
time_per_km = 0.2
permission_cost = 5000

# Calculate the total cost and time for each route
routes['Total Cost'] = routes['Distance'] * cost_per_km + routes['Government Permission'] * permission_cost
routes['Total Time'] = routes['Distance'] * time_per_km + routes['Traffic'] * routes['Distance']

# Find the index of the best route
best_route_index = routes[['Total Cost', 'Total Time']].idxmin()

# Print the best route
print(f'The best route is: Route {best_route_index["Total Cost"]+1 if best_route_index["Total Cost"] == best_route_index["Total Time"] else best_route_index["Total Time"]+1}')

# Extract the information of the best route
best_route = routes.loc[best_route_index]

# Print the information of the best route
print(best_route)
# Out:
# The best route is: Route 1
#   Route  Distance  Traffic  Government Permission  Total Cost  Total Time
# 1     B        15      0.2                      0         150         6.0
# 0     A        10      0.1                      1        5100         3.0

# %%
routes
# Out:
#   Route  Distance  Traffic  Government Permission  Total Cost  Total Time
# 0     A        10      0.1                      1        5100         3.0
# 1     B        15      0.2                      0         150         6.0

# %% [markdown]
# ##Problem 17: Multiple treatment options
# You are an environmental engineer and you are designing a treatment system for a contaminated site. You have multiple treatment options to choose from and you need to decide which option is the most cost-effective in terms of both capital and operational costs.
#
# Python code to solve the problem:
#
# In this example, we use a pandas DataFrame to store the information for the three potential treatment options. The Total cost is calculated by summing up the capital cost and operational costs. then we use the idxmin() method to find the index of the best option, considering the minimum total cost. We then use this index to extract the information of the best option. Finally, we print the best option and it's information. To visualize the data, we use bar plot to show the total cost of each treatment option and highlight the best option in red.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a dataframe with treatment options information
treatment_options = pd.DataFrame({'Option': ['A', 'B', 'C'],
                                  'Capital Cost': [10000, 15000, 20000],
                                  'Operational Cost': [500, 800, 1000]})


# Calculate the total cost for each option
treatment_options['Total Cost'] = treatment_options['Capital Cost'] + treatment_options['Operational Cost']

# Find the index of the best option
best_option_index = treatment_options['Total Cost'].idxmin()

# Print the best option
print(f'The best treatment option is: Option {best_option_index+1}')

# Extract the information of the best option
best_option = treatment_options.loc[best_option_index]

# Print the information of the best option
print(best_option)

# Plot the results
fig, ax = plt.subplots()
ax.bar(treatment_options['Option'], treatment_options['Total Cost'], label='Treatment Options')
ax.bar(best_option['Option'], best_option['Total Cost'], color='r', label='Best Option')
ax.set_xlabel('Treatment Options')
ax.set_ylabel('Total Cost')
plt.legend()
plt.show()
# Out:
# The best treatment option is: Option 1
# Option                  A
# Capital Cost        10000
# Operational Cost      500
# Total Cost          10500
# Name: 0, dtype: object

# %%
treatment_options
# Out:
#   Option  Capital Cost  Operational Cost  Total Cost
# 0      A         10000               500       10500
# 1      B         15000               800       15800
# 2      C         20000              1000       21000

# %% [markdown]
# ##Problem 18: Material selection
# You are a civil engineer and you need to decide on the best material for a bridge deck. You have three options: steel, concrete, and wood. The life cycle cost of each material is different and you need to decide which material is the most cost-effective over the 50-year life of the bridge.
#
# Python code to solve the problem:
#
# In this example, we use a pandas DataFrame to store the information for the three potential material options. The Life cycle cost is calculated by summing up the initial cost, maintenance costs over 50 years, and replacement costs. then we use the idxmin() method to find the index of the best option, considering the minimum life cycle cost. We then use this index to extract the information of the best option. Finally, we print the best option and it's information. To visualize the data, we use a bar plot to show the life cycle cost of each material option and highlight the best option in red.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a dataframe with material options information
material_options = pd.DataFrame({'Option': ['Steel', 'Concrete', 'Wood'],
                                 'Initial Cost': [100000, 150000, 120000],
                                 'Maintenance Cost': [5000, 10000, 2000],
                                 'Replacement Cost': [50000, 100000, 80000]})

# Calculate the life cycle cost for each option
material_options['Life Cycle Cost'] = material_options['Initial Cost'] + material_options['Maintenance Cost']*50 + material_options['Replacement Cost']

# Find the index of the best option
best_option_index = material_options['Life Cycle Cost'].idxmin()

# Print the best option
print(f'The best material option is: {material_options.loc[best_option_index]["Option"]}')

# Extract the information of the best option
best_option = material_options.loc[best_option_index]

# Print the information of the best option
print(best_option)

# Plot the results
fig, ax = plt.subplots()
ax.bar(material_options['Option'], material_options['Life Cycle Cost'], label='Material Options')
ax.bar(best_option['Option'], best_option['Life Cycle Cost'], color='r', label='Best Option')
ax.set_xlabel('Material Options')
ax.set_ylabel('Life Cycle Cost')
plt.legend()
plt.show()
# Out:
# The best material option is: Wood
# Option                Wood
# Initial Cost        120000
# Maintenance Cost      2000
# Replacement Cost     80000
# Life Cycle Cost     300000
# Name: 2, dtype: object

# %%
material_options
# Out:
#      Option  Initial Cost  Maintenance Cost  Replacement Cost  Life Cycle Cost
# 0     Steel        100000              5000             50000           400000
# 1  Concrete        150000             10000            100000           750000
# 2      Wood        120000              2000             80000           300000

# %% [markdown]
# ##Problem 19: Monte Carlo simulation
# Use Monte Carlo simulation to estimate the probability of failure of a bridge, given a load distribution and material properties.
#
# Python code to solve the problem:
#
# This code uses the Monte Carlo simulation to estimate the probability of failure of a bridge given the load distribution and material properties. The code defines the number of Monte Carlo samples, mean load, standard deviation of the load and yield strength of the material. Then it runs a loop where it generates random load and random material properties. It checks if load is greater than strength, if it is true it increases the failure count. Finally it calculates the probability of failure and prints it.
#
# This is just one example of how you could use Monte Carlo simulation to estimate the probability of failure of a bridge or any other structure. You can use this approach to estimate the probability of failure for different load distributions and material properties.

# %%
import random
import numpy as np

# Define inputs
n_samples = 100000  # number of Monte Carlo samples
load_mean = 170  # mean load (kN)
load_stddev = 2  # load standard deviation (kN)

resistance = 200  #  strength of material (KN)

# Initialize failure count
failures = 0

# Run Monte Carlo simulation
for i in range(n_samples):
    # Generate random load
    load = random.gauss(load_mean, load_stddev)
    # Generate random material properties
    strength = random.gauss(resistance, resistance*0.1)

    # Check for failure
    if load > strength:
        failures += 1

# Calculate probability of failure
p_fail = failures / n_samples

# Print result
print("Probability of failure: {:.2f}%".format(p_fail*100))
# Out:
# Probability of failure: 6.74%

# %% [markdown]
# ##Problem 20: Optimize traffic signal timing
# Determine the optimal traffic signal timing for a four-way intersection. The intersection has four approaches and the traffic flow on each approach is measured in vehicles per hour. The objective is to minimize the total delay experienced by vehicles at the intersection.
#
# Python code to solve the problem:
#
# This code uses the minimize function from scipy library to minimize the total delay experienced by vehicles at the intersection. The minimize function is a function that minimize a given function. The function defined in objective is the function that should be minimized, in this case, it is the total delay experienced by vehicles at the intersection. The constraints are defined in the constraint1 function, which is the total cycle
#
# time being equal to the sum of the green time for each approach.
# The scipy library is a python library for optimization and scientific computing, it provides an efficient way to solve the mathematical optimization problems. The function minimize() is used to find the optimal solution, in this case, the optimal green time for each approach. The results are printed out in the last line of the code.

# %%
from scipy.optimize import minimize

# Define inputs
flow = [1000, 800, 600, 700]  # traffic flow on each approach (veh/hr)
cycle_time = 120  # total cycle time (s)
green_time = [30, 40, 50, 40]  # initial green time for each approach (s)

# Define the objective function
def objective(x):
    delay = 0
    for i in range(4):
        delay += (flow[i]/3600)*(cycle_time - x[i])
    return delay

# Define the constraints
def constraint1(x):
    return cycle_time - sum(x)

# Set the bounds
b = (0, cycle_time)
bnds = [b, b, b, b]

# Solve the optimization problem
sol = minimize(objective, green_time, bounds=bnds, constraints={"type": "eq", "fun": constraint1})

print("Optimal green time for each approach: ", sol.x)
# Out:
# Optimal green time for each approach:  [1.20000000e+02 1.81188398e-13 0.00000000e+00 0.00000000e+00]

# %% [markdown]
# ##Problem 21: Optimize cantilever beam
# You are designing a cantilever beam of fixed length L, and you want to minimize the weight of the beam while maintaining a minimum factor of safety against buckling. The buckling factor of safety is given by the ratio of the critical load to the applied load.
#
# Python code to solve the problem:
#
# In this example, the objective function is to minimize the weight of the beam, which is represented by the product of the cross-sectional area (x[0]), the material density (x[1]), and the length of the beam (x[2]). The constraint ensures that the buckling factor of safety is greater than or equal to 2, which is represented by the ratio of the critical load (π²EI/(L²)) to the applied load (P). The minimize function from the scipy.optimize library is used to minimize the objective function subject to the constraint. The solution returned by the minimize function, contains the optimal values of the design variables and other information such as the success of the optimization, the number of iterations, etc.

# %%
from scipy.optimize import minimize
import numpy as np

P = 100   #Load
def objective(x):
    """ objective function to minimize """
    return x[0]*x[1]*x[2]

def constraint(x):
    """ constraint : buckling factor of safety >= 2 """
    return (np.pi**2*x[0]/(x[1]*x[2]))/P-2

# Initial guess
x0 = [1, 1, 1]

# Bounds
b = (0.1, 10)
bnds = (b, b, b)

# Constraints
con1 = {'type': 'ineq', 'fun': constraint}
cons = ([con1])

# minimize the objective function
sol = minimize(objective, x0, bounds=bnds, constraints=cons)

print(sol)
# Out:
#      fun: 0.0020264236821680905
#      jac: array([0.01      , 0.02026424, 0.02026424])
#  message: 'Optimization terminated successfully'
#     nfev: 36
#      nit: 9
#     njev: 9
#   status: 0
#  success: True
#        x: array([0.20264237, 0.1       , 0.1       ])
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/optimize.py:282: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "

# %% [markdown]
# ##Problem 22: Design a truss
# Design a simple truss by determining the force in each member of a truss, given the loads and geometry of the truss.
#
# Python code to solve the problem:

# %%
import numpy as np

# Define inputs
E = 200e9  # modulus of elasticity (Pa)
A = 0.0002  # cross-sectional area (m^2)
P = 100e3  # load (N)

# Define coordinates of joints
coords = np.array([[0,0], [5,0], [5,3], [0,3], [2.5,6]])

# Define connectivity of joints
connectivity = np.array([[0,1], [1,2], [2,3], [3,0], [0,2], [1,4], [2,4], [3,4]])

# Define loads
loads = np.zeros(len(coords)*2)
loads[5] = -P

# Create global stiffness matrix
K_global = np.zeros((len(coords)*2, len(coords)*2))

# Assemble stiffness matrix
for i in range(len(connectivity)):
    node1 = connectivity[i,0]
    node2 = connectivity[i,1]
    x1,y1 = coords[node1]
    x2,y2 = coords[node2]
    L = ((x2-x1)**2 + (y2-y1)**2)**0.5
    c = (x2-x1)/L
    s = (y2-y1)/L
    k_local = np.array([[c*c, c*s, -c*c, -c*s],
                        [c*s, s*s, -c*s, -s*s],
                        [ -c*c, -c*s, c*c, c*s],
                        [ -c*s, -s*s, c*s, s*s]])*(E*A/L)
    for j in range(2):
        for k in range(2):
            K_global[2*node1+j, 2*node1+k] += k_local[j,k]
            K_global[2*node2+j, 2*node2+k] += k_local[j+2,k+2]
            K_global[2*node1+j, 2*node2+k] -= k_local[j,k+2]
            K_global[2*node2+j, 2*node1+k] -= k_local[j+2,k]

# Solve for nodal displacements
displacements = np.linalg.solve(K_global, loads)

# Solve for member forces
forces = np.zeros(len(connectivity))
for i in range(len(connectivity)):
    node1 = connectivity[i,0]
    node2 = connectivity[i,1]
    x1,y1 = coords[node1]
    x2,y2 = coords[node2]
    L = ((x2-x1)**2 + (y2-y1)**2)**0.5
    c = (x2-x1)/L
    s = (y2-y1)/L
    T = np.array([-c, -s, c, s])
    forces[i] = T@np.array([displacements[2*node1], displacements[2*node1+1], displacements[2*node2], displacements[2*node2+1]])

print(forces)
# Out:
# [ 1.01408950e+13  3.97682157e+12  1.90887435e+13  1.88899025e+13
#   1.84145204e+13  7.57125645e+12  9.16523687e+12 -2.29130922e+12]

# %% [markdown]
# ## Problem 23: Simulate flow of traffic
# Simulate the flow of traffic on a highway using a cellular automata model. The simulation should model the behavior of vehicles on a highway with one lane and a maximum speed of 20 m/s.

# %% [markdown]
# The following code use the Intelligent Driver Model (IDM) to simulate the flow of traffic on a highway with one lane and a maximum speed of 20 m/s. The code uses the density of vehicles, maximum speed, and length of the highway to initialize the simulation, then it runs a loop which updates the positions and velocities of the vehicles at each time step. The code uses the Intelligent Driver Model to update the velocities of the vehicles based on the distance to the next vehicle.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define inputs
L = 1000  # length of highway (m)
v_max = 20  # maximum speed (m/s)
density = 0.1  # vehicle density (vehicles/m)
timestep = 10  # simulation timestep (s)

# Initialize simulation
N = int(density * L)  # number of vehicles
positions = np.random.rand(N) * L  # initial vehicle positions (m)
velocities = np.random.rand(N) * v_max  # initial vehicle velocities (m/s)

# Simulation loop
for t in range(10):
    # Update vehicle positions
    positions += velocities * timestep

    # Update vehicle velocities
    for i in range(N):
        # Calculate distance to next vehicle
        distance_ahead = float("inf")
        for j in range(N):
            if j != i:
                distance = positions[j] - positions[i]
                if distance > 0 and distance < distance_ahead:
                    distance_ahead = distance

        # Update velocity according to the Intelligent Driver Model
        v_desired = min(v_max, distance_ahead)
        acceleration = 1  # constant acceleration
        velocities[i] = min(velocities[i] + acceleration * timestep, v_desired)
   
    # Creat highway raster
    highway = np.zeros([L,2])
    for i in range(len(highway)):
      if i in positions.astype(int):
        highway[i,0] = 1.0


    # Plot the highway
    print('Time step: {} seconds'.format(t*timestep))
    plt.figure(figsize=(12, 1))
    plt.imshow(highway.T, cmap='gray_r',  aspect=6)
    plt.axis('off')
    plt.show()
    print('')
# Out:
# Time step: 0 seconds
# Time step: 10 seconds
# Time step: 20 seconds
# Time step: 30 seconds
# Time step: 40 seconds
# Time step: 50 seconds
# Time step: 60 seconds
# Time step: 70 seconds
# Time step: 80 seconds
# Time step: 90 seconds

# %% [markdown]
# ##Problem 24: Time-temperature response of a concrete slab
# Determine the time-temperature response of a concrete slab under fire conditions. The slab has a thickness of 0.2m, a thermal conductivity of 1W/m.K, and a heat transfer coefficient of 10W/m^2.K. The initial temperature of the slab is 20C and the ambient temperature is 800C.
#
# Python code to solve the problem:
#
# This code uses basic mathematical formulas to calculate the time-temperature response of the concrete slab under fire conditions. It uses the numpy library to perform mathematical operations and to create the time array. The code then uses the matplotlib library to plot the time-temperature response. The x-axis represents the time and the y-axis represents the temperature.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define inputs
t = 0.2  # thickness of the slab (m)
k = 1  # thermal conductivity of the slab (W/m.K)
h = 10  # heat transfer coefficient (W/m^2.K)
T_init = 20  # initial temperature of the slab (C)
T_inf = 800  # ambient temperature (C)

# Calculate the time constant
tau = t/(h+k)

# Calculate the time-temperature response
time = np.linspace(0, 1, 100)
T = T_init + (T_inf - T_init)*(1-np.exp(-time/tau))

# Plot the time-temperature response
plt.plot(time, T)
plt.xlabel('Time (s)')
plt.ylabel('Temperature (C)')
plt.title('Time-temperature response')
plt.show()

# %% [markdown]
# ##Problem 25: Velocity and acceleration of a particle
# Determine the velocity and acceleration of a particle moving in a circular path. The particle has a constant speed of 5m/s and the radius of the circular path is 2m.
#
# Python code to solve the problem:
#
# The code uses the numpy library to create the time array and to perform mathematical operations to calculate the velocity and acceleration of the particle in the x and y direction. The code then uses the matplotlib library to plot the results in four subplots, the first two subplots show the velocity in the x and y direction, and the last two subplots show the acceleration in the x and y direction. The x-axis represents the time and the y-axis represents the velocity and acceleration.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define inputs
v = 5  # speed of the particle (m/s)
r = 2  # radius of the circular path (m)

# Define time array
t = np.linspace(0, 2*np.pi, 100)

# Calculate the velocity and acceleration in x and y direction
vx = v*np.cos(t)
vy = v*np.sin(t)
ax = -v*np.sin(t)
ay = v*np.cos(t)

# Plot the velocity and acceleration
plt.subplot(2, 2, 1)
plt.plot(t, vx)
plt.xlabel('Time (s)')
plt.ylabel('Velocity x (m/s)')
plt.title('Velocity in x direction')

plt.subplot(2, 2, 2)
plt.plot(t, vy)
plt.xlabel('Time (s)')
plt.ylabel('Velocity y (m/s)')
plt.title('Velocity in y direction')

plt.subplot(2, 2, 3)
plt.plot(t, ax)
plt.xlabel('Time (s)')
plt.ylabel('Acceleration x (m/s^2)')
plt.title('Acceleration in x direction')

plt.subplot(2, 2, 4)
plt.plot(t, ay)
plt.xlabel('Time (s)')
plt.ylabel('Acceleration y (m/s^2)')
plt.title('Acceleration in y direction')

plt.subplots_adjust(hspace=0.4)
plt.show()

# %% [markdown]
# ##Problem 26: Pollutant concentration
# Simulate the temporal variation of pollutant concentration in a water body, given the initial concentration, decay constant, and pollutant release rate. The code uses python and the numpy and matplotlib libraries to calculate the concentration at different points in time and then plots the results to visualize the temporal variation of the pollutant concentration.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define inputs
C0 = 100 # Initial concentration (mg/L)
k = 0.05 # Decay constant (1/day)
Q = 10 # Pollutant release rate (mg/day)
t = np.linspace(0, 30, 100) # Time (days)

# Calculate the concentration
C = C0 + (Q/k) * (1 - np.exp(-k*t))

# Plot the results
plt.plot(t, C)
plt.xlabel('Time (days)')
plt.ylabel('Concentration (mg/L)')
plt.title('Temporal variation of pollutant concentration')
plt.show()

# %% [markdown]
# ##Problem 27: Pavement material selection
# Compare the cost and environmental impact of different pavement materials for a road project. The materials considered are asphalt, concrete and permeable pavement.
# Python code to solve the problem:
# This code uses a simple decision-making approach by creating a cost score for each material, by adding the environmental impact (multiplied by a factor) to the sum of construction and life-cycle costs. It then sorts the scores and determines the best material. The matplotlib library is used to plot the results.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define inputs
materials = ["Asphalt", "Concrete", "Permeable"]
cost = [500000, 800000, 600000] # Construction cost (USD)
life_cycle_cost = [600000, 900000, 700000] # Life-cycle cost (USD)
environmental_impact = [2, 3, 1] # Environmental impact (1-5 scale)

# Decision making
scores = []
for i in range(len(materials)):
    score = cost[i] + life_cycle_cost[i] + environmental_impact[i]*100_000
    scores.append([materials[i], score])

scores = sorted(scores, key=lambda x: x[1], reverse=False)
best_material = scores[0][0]

# Plotting the results
x = [material for material, _ in scores]
y = [score for _, score in scores]
plt.bar(x, y)
plt.xlabel('Materials')
plt.ylabel('Scores')
plt.title('Decision making for pavement material')
plt.show()

print("The best material for the pavement is: ", best_material)
# Out:
# The best material for the pavement is:  Asphalt
